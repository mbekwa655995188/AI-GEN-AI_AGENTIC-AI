# %%
1
2
1+2
# Out:
# 3

# %%
1+3
# Out:
# 4

# %%
10+5
# Out:
# 15

# %%
10+5-(2*3)
# Out:
# 9

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])|# linear (y = mx + c )

# %%
plt.plot([1,2,3,4],[1,4,9,16])#

# %%
9
# Out:
# 9

# %%
_+ 3
# Out:
# 12

# %%
_+ 3
# Out:
# 15
